# %%
class standardClass:
    # cant variable without typing or default value
    # dec
    dec2 = 2
    def __init__(self,dec,dec3,dec4=4):
        self.dec = dec
        self.dec3 = dec3
        self.dec4 = dec4
    def varis(self):
        print(self.dec,self.dec2,self.dec3,self.dec4)

# %%
t = standardClass(1,3)
t.varis()
# Out:
# 1 2 3 4

# %%
class sharedVaries:
    listvalue = [1,2,3]

# %%
t2 = sharedVaries()
t3 = sharedVaries()
t2.listvalue.append(4)
print(t3.listvalue)
# Out:
# [1, 2, 3, 4]

# %%
t3.listvalue.clear()
print(t2.listvalue)
# Out:
# []

# %%
class Person:
    agent = "Mikey"
    age = 10
    pet = "dog"
    def __init__(self,snack="Cookies"):
        self.snack = snack
    def greet(self):
        print(f"Hello my name is {self.agent}, i am {self.age} old and i have a pet {self.pet}")

# %%
p1 = Person()
p2 = Person()
p1.greet()
# Out:
# Hello my name is Mikey, i am 10 old and i have a pet dog

# %%
p1.age = 11
p1.greet()
# Out:
# Hello my name is Mikey, i am 11 old and i have a pet dog

# %%
print(p1.snack)
del p1.snack
try:
    print(p1.snack)
except:
    print("Missing attribute snack")
# Out:
# Cookies
# Missing attribute snack

# %%
print(Person.age)
del Person.age
try:
    print(Person.age)
except:
    print("Missing attribute age")
# Out:
# 10
# Missing attribute age

# %%
try:
    print(p2.age)
except:
    print("Missing attribute age")
# Out:
# Missing attribute age

# %%
p3 = Person()
p3.age = 11
print(p3.age)
# Out:
# 11

# %%
def showAndTell(self):
    print(f"My show and tell object is my pet which is a {self.pet}")
p3.show = showAndTell
p3.show(p3)
# Out:
# My show and tell object is my pet which is a dog

# %%
try:
    print(Person.age)
except:
    print("Missing attribute age")
# Out:
# Missing attribute age

# %%
Person.age = 10
print(Person.age)
# Out:
# 10

# %%
print(p2.age)
# Out:
# 10

# %%
def greetEvil():
    print("HAHA, it was me, DIO")

# %%
p3.greet = greetEvil
p3.greet()
# Out:
# HAHA, it was me, DIO

# %%
p2.greet()
# Out:
# Hello my name is Mikey, i am 10 old and i have a pet dog

# %%
Person.greet = greetEvil
try:
    p1.greet()
except Exception as e:
    print(e)
# Out:
# greetEvil() takes 0 positional arguments but 1 was given

# %%
def greetEvilForClass(self=None):
    print("HAHA, it was me, DIO")

# %%
Person.greet = greetEvilForClass
p1.greet()
# Out:
# HAHA, it was me, DIO
